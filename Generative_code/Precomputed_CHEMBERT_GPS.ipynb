# %% [markdown]
# <a href="https://colab.research.google.com/github/raphaelrubrice/BornToOverfit/blob/raph/Precomputed_CHEMBERT_GPS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Running the best GPS with KNN Generate**
# <a href="https://colab.research.google.com/github/raphaelrubrice/BornToOverfit/blob/raph/Precomputed_CHEMBERT_GPS.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Colab setup**

# %%
from google.colab import drive
drive.mount('/content/drive')
# to avoid having the data on your drive
# %cd /content
# Out:
# Mounted at /content/drive
# /content

# %%
# !git clone https://github.com/raphaelrubrice/BornToOverfit.git
# %cd BornToOverfit
# !git checkout raph
# Out:
# Cloning into 'BornToOverfit'...
# remote: Enumerating objects: 731, done.
# remote: Counting objects: 100% (57/57), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 731 (delta 35), reused 35 (delta 24), pack-reused 674 (from 1)
# Receiving objects: 100% (731/731), 1.06 MiB | 3.54 MiB/s, done.
# Resolving deltas: 100% (500/500), done.
# /content/BornToOverfit
# Branch 'raph' set up to track remote branch 'raph' from 'origin'.
# Switched to a new branch 'raph'

# %% [markdown]
# Installing requirements

# %%
# !pip install -r data_baseline/requirements.txt
# Out:
# Requirement already satisfied: torch>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from -r data_baseline/requirements.txt (line 1)) (2.9.0+cu126)
# Collecting torch-geometric>=2.3.0 (from -r data_baseline/requirements.txt (line 2))
#   Downloading torch_geometric-2.7.0-py3-none-any.whl.metadata (63 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 3.6 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from -r data_baseline/requirements.txt (line 3)) (2.2.2)
# Requirement already satisfied: transformers>=4.30.0 in /usr/local/lib/python3.12/dist-packages (from -r data_baseline/requirements.txt (line 4)) (4.57.3)
# Requirement already satisfied: tqdm>=4.65.0 in /usr/local/lib/python3.12/dist-packages (from -r data_baseline/requirements.txt (line 5)) (4.67.1)
# Collecting rdkit>=2023.3.1 (from -r data_baseline/requirements.txt (line 6))
#   Downloading rdkit-2025.9.3-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: nltk>=3.8.0 in /usr/local/lib/python3.12/dist-packages (from -r data_baseline/requirements.txt (line 7)) (3.9.1)
# Requirement already satisfied: peft in /usr/local/lib/python3.12/dist-packages (from -r data_baseline/requirements.txt (line 8)) (0.18.0)
# Collecting bitsandbytes (from -r data_baseline/requirements.txt (line 9))
#   Downloading bitsandbytes-0.49.1-py3-none-manylinux_2_24_x86_64.whl.metadata (10 kB)
# Collecting sacrebleu (from -r data_baseline/requirements.txt (line 10))
#   Downloading sacrebleu-2.6.0-py3-none-any.whl.metadata (39 kB)
# Collecting bert-score (from -r data_baseline/requirements.txt (line 11))
#   Downloading bert_score-0.3.13-py3-none-any.whl.metadata (15 kB)
# Collecting evaluate (from -r data_baseline/requirements.txt (line 12))
#   Downloading evaluate-0.4.6-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: datasets in /usr/local/lib/python3.12/dist-packages (from -r data_baseline/requirements.txt (line 13)) (4.0.0)
# Requirement already satisfied: accelerate in /usr/local/lib/python3.12/dist-packages (from -r data_baseline/requirements.txt (line 14)) (1.12.0)
# Collecting trl (from -r data_baseline/requirements.txt (line 15))
#   Downloading trl-0.26.2-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r data_baseline/requirements.txt (line 1)) (3.20.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r data_baseline/requirements.txt (line 1)) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r data_baseline/requirements.txt (line 1)) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r data_baseline/requirements.txt (line 1)) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r data_baseline/requirements.txt (line 1)) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r data_baseline/requirements.txt (line 1)) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r data_baseline/requirements.txt (line 1)) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r data_baseline/requirements.txt (line 1)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r data_baseline/requirements.txt (line 1)) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r data_baseline/requirements.txt (line 1)) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r data_baseline/requirements.txt (line 1)) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r data_baseline/requirements.txt (line 1)) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r data_baseline/requirements.txt (line 1)) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r data_baseline/requirements.txt (line 1)) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r data_baseline/requirements.txt (line 1)) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r data_baseline/requirements.txt (line 1)) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r data_baseline/requirements.txt (line 1)) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r data_baseline/requirements.txt (line 1)) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r data_baseline/requirements.txt (line 1)) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r data_baseline/requirements.txt (line 1)) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r data_baseline/requirements.txt (line 1)) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r data_baseline/requirements.txt (line 1)) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch>=2.0.0->-r data_baseline/requirements.txt (line 1)) (3.5.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.12/dist-packages (from torch-geometric>=2.3.0->-r data_baseline/requirements.txt (line 2)) (3.13.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from torch-geometric>=2.3.0->-r data_baseline/requirements.txt (line 2)) (2.0.2)
# Requirement already satisfied: psutil>=5.8.0 in /usr/local/lib/python3.12/dist-packages (from torch-geometric>=2.3.0->-r data_baseline/requirements.txt (line 2)) (5.9.5)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.12/dist-packages (from torch-geometric>=2.3.0->-r data_baseline/requirements.txt (line 2)) (3.3.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (from torch-geometric>=2.3.0->-r data_baseline/requirements.txt (line 2)) (2.32.4)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.12/dist-packages (from torch-geometric>=2.3.0->-r data_baseline/requirements.txt (line 2)) (3.6.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->-r data_baseline/requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->-r data_baseline/requirements.txt (line 3)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.5.0->-r data_baseline/requirements.txt (line 3)) (2025.3)
# Requirement already satisfied: huggingface-hub<1.0,>=0.34.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.30.0->-r data_baseline/requirements.txt (line 4)) (0.36.0)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.30.0->-r data_baseline/requirements.txt (line 4)) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.30.0->-r data_baseline/requirements.txt (line 4)) (6.0.3)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.30.0->-r data_baseline/requirements.txt (line 4)) (2025.11.3)
# Requirement already satisfied: tokenizers<=0.23.0,>=0.22.0 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.30.0->-r data_baseline/requirements.txt (line 4)) (0.22.2)
# Requirement already satisfied: safetensors>=0.4.3 in /usr/local/lib/python3.12/dist-packages (from transformers>=4.30.0->-r data_baseline/requirements.txt (line 4)) (0.7.0)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from rdkit>=2023.3.1->-r data_baseline/requirements.txt (line 6)) (11.3.0)
# Requirement already satisfied: click in /usr/local/lib/python3.12/dist-packages (from nltk>=3.8.0->-r data_baseline/requirements.txt (line 7)) (8.3.1)
# Requirement already satisfied: joblib in /usr/local/lib/python3.12/dist-packages (from nltk>=3.8.0->-r data_baseline/requirements.txt (line 7)) (1.5.3)
# Collecting portalocker (from sacrebleu->-r data_baseline/requirements.txt (line 10))
#   Downloading portalocker-3.2.0-py3-none-any.whl.metadata (8.7 kB)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.12/dist-packages (from sacrebleu->-r data_baseline/requirements.txt (line 10)) (0.9.0)
# Collecting colorama (from sacrebleu->-r data_baseline/requirements.txt (line 10))
#   Downloading colorama-0.4.6-py2.py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: lxml in /usr/local/lib/python3.12/dist-packages (from sacrebleu->-r data_baseline/requirements.txt (line 10)) (6.0.2)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.12/dist-packages (from bert-score->-r data_baseline/requirements.txt (line 11)) (3.10.0)
# Requirement already satisfied: dill in /usr/local/lib/python3.12/dist-packages (from evaluate->-r data_baseline/requirements.txt (line 12)) (0.3.8)
# Requirement already satisfied: multiprocess in /usr/local/lib/python3.12/dist-packages (from evaluate->-r data_baseline/requirements.txt (line 12)) (0.70.16)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.12/dist-packages (from datasets->-r data_baseline/requirements.txt (line 13)) (18.1.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric>=2.3.0->-r data_baseline/requirements.txt (line 2)) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric>=2.3.0->-r data_baseline/requirements.txt (line 2)) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric>=2.3.0->-r data_baseline/requirements.txt (line 2)) (25.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric>=2.3.0->-r data_baseline/requirements.txt (line 2)) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric>=2.3.0->-r data_baseline/requirements.txt (line 2)) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric>=2.3.0->-r data_baseline/requirements.txt (line 2)) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp->torch-geometric>=2.3.0->-r data_baseline/requirements.txt (line 2)) (1.22.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub<1.0,>=0.34.0->transformers>=4.30.0->-r data_baseline/requirements.txt (line 4)) (1.2.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5.0->-r data_baseline/requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric>=2.3.0->-r data_baseline/requirements.txt (line 2)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric>=2.3.0->-r data_baseline/requirements.txt (line 2)) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric>=2.3.0->-r data_baseline/requirements.txt (line 2)) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests->torch-geometric>=2.3.0->-r data_baseline/requirements.txt (line 2)) (2026.1.4)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch>=2.0.0->-r data_baseline/requirements.txt (line 1)) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch>=2.0.0->-r data_baseline/requirements.txt (line 1)) (3.0.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score->-r data_baseline/requirements.txt (line 11)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score->-r data_baseline/requirements.txt (line 11)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score->-r data_baseline/requirements.txt (line 11)) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib->bert-score->-r data_baseline/requirements.txt (line 11)) (1.4.9)
# Downloading torch_geometric-2.7.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 35.1 MB/s eta 0:00:00
# Downloading rdkit-2025.9.3-cp312-cp312-manylinux_2_28_x86_64.whl (36.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 36.4/36.4 MB 77.2 MB/s eta 0:00:00
# Downloading bitsandbytes-0.49.1-py3-none-manylinux_2_24_x86_64.whl (59.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.1/59.1 MB 46.8 MB/s eta 0:00:00
# Downloading sacrebleu-2.6.0-py3-none-any.whl (100 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 100.8/100.8 kB 11.2 MB/s eta 0:00:00
# Downloading bert_score-0.3.13-py3-none-any.whl (61 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 kB 7.9 MB/s eta 0:00:00
# Downloading evaluate-0.4.6-py3-none-any.whl (84 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 84.1/84.1 kB 11.8 MB/s eta 0:00:00
# Downloading trl-0.26.2-py3-none-any.whl (518 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 518.9/518.9 kB 55.3 MB/s eta 0:00:00
# Downloading colorama-0.4.6-py2.py3-none-any.whl (25 kB)
# Downloading portalocker-3.2.0-py3-none-any.whl (22 kB)
# Installing collected packages: rdkit, portalocker, colorama, sacrebleu, torch-geometric, bitsandbytes, trl, evaluate, bert-score
# Successfully installed bert-score-0.3.13 bitsandbytes-0.49.1 colorama-0.4.6 evaluate-0.4.6 portalocker-3.2.0 rdkit-2025.9.3 sacrebleu-2.6.0 torch-geometric-2.7.0 trl-0.26.2

# %% [markdown]
# **Downloading the data**

# %%
# !cp -r /content/drive/MyDrive/MVA/ALTEGRAD/challenge_data/data /content/BornToOverfit/data_baseline/.

# %% [markdown]
# ## **KNN Generate**

# %% [markdown]
# Add Molecule cards

# %%
# !python data_baseline/data_utils.py
# Out:
# ====================================================================================================
# BUILD + SAVE: mol_card for all graphs
# ====================================================================================================
#
# [1/3] Loading: /content/BornToOverfit/data_baseline/data/train_graphs.pkl
# Loaded graphs: 31008
# Adding Molecule Cards..: 100% 31008/31008 [01:13<00:00, 423.09it/s]
# Added/updated mol_card for: 31008
# [2/3] Saving back to same location: /content/BornToOverfit/data_baseline/data/train_graphs.pkl
# [3/3] Reloading to verify mol_card persisted: /content/BornToOverfit/data_baseline/data/train_graphs.pkl
#
# --- Sample mol_card (first graph) ---
# [MOL_FEATURES]
# SMILES: NC1=C2N=CN([C@@H]3O[C@H](COP(=O)([O-])OP(=O)([O-])OC4O[C@H](CO)[C@@H](O)[C@H]4O)[C@@H](O)[C@H]3OP(=O)([O-])[O-])C2=NC=N1
# atoms_total: 40
# elements: C=15 N=5 O=17 P=3
# molecular_weight: 635.265000
# high_natural_abundance_atoms: 25
# nuclear_spins: 1:5; 1/2:3
# halogens_total: 0
# metals_or_other_total: 0
# formal_charge_net: -4
# aromatic_atoms: 9
# ring_atoms: 19
# undirected_bonds: 43
# bond_types: SINGLE=30 DOUBLE=3 AROMATIC=10
# conjugated_bonds: 11
# hybridization: SP2=13 SP3=27
# chirality_centers: 7
# radical_atoms: 0
# tags: net_negative_charge(-4); contains_P_and_O; aromatic_character; ring_system; heteroatom_rich
# [/MOL_FEATURES]
#
# --- Ground-truth description (truncated) ---
# The molecule is tetraanion of ADP-D-ribose 2'-phosphate. It has a role as a human metabolite. It is a conjugate base of an ADP-D-ribose 2'-phosphate.
#
# OK: train_graphs.pkl updated and verified.
#
# [1/3] Loading: /content/BornToOverfit/data_baseline/data/validation_graphs.pkl
# Loaded graphs: 1000
# Adding Molecule Cards..: 100% 1000/1000 [00:02<00:00, 379.29it/s]
# Added/updated mol_card for: 1000
# [2/3] Saving back to same location: /content/BornToOverfit/data_baseline/data/validation_graphs.pkl
# [3/3] Reloading to verify mol_card persisted: /content/BornToOverfit/data_baseline/data/validation_graphs.pkl
#
# --- Sample mol_card (first graph) ---
# [MOL_FEATURES]
# SMILES: CC(=O)N[C@H]1[C@H](O[C@H]2[C@H](O)[C@@H](O)[C@H](O[C@H]3[C@@H](OS(=O)(=O)O)[C@@H](CO)OC(O)[C@@H]3NC(C)=O)O[C@@H]2C(=O)O)O[C@H](CO)[C@H](OS(=O)(=O)O)[C@@H]1O[C@H]1O[C@@H](C(=O)O)[C@@H](O)[C@H](O)[C@H]1OS(=O)(=O)O
# atoms_total: 65
# elements: C=28 N=2 O=32 S=3
# molecular_weight: 1016.822000
# high_natural_abundance_atoms: 34
# nuclear_spins: 1:2
# halogens_total: 0
# metals_or_other_total: 0
# formal_charge_net: 0
# aromatic_atoms: 0
# ring_atoms: 24
# undirected_bonds: 68
# bond_types: SINGLE=58 DOUBLE=10
# conjugated_bonds: 8
# hybridization: SP2=18 SP3=47
# chirality_centers: 19
# radical_atoms: 0
# tags: contains_S_and_O; ring_system; heteroatom_rich
# [/MOL_FEATURES]
#
# --- Ground-truth description (truncated) ---
# The molecule is an amino tetrasaccharide comprised of an L-iduronic acid residue, sulfated on O-2, a glucuronic acid residue, and two N-acetylated galactosamine residues, one of which is at the reducing end and both of which are sulfated on O-4. It is an intermediate in the chondroitin sulfate degradation pathway. It has a role as a mouse metabolite.
#
# OK: validation_graphs.pkl updated and verified.
#
# [1/3] Loading: /content/BornToOverfit/data_baseline/data/test_graphs.pkl
# Loaded graphs: 1000
# Adding Molecule Cards..: 100% 1000/1000 [00:02<00:00, 419.96it/s]
# Added/updated mol_card for: 1000
# [2/3] Saving back to same location: /content/BornToOverfit/data_baseline/data/test_graphs.pkl
# [3/3] Reloading to verify mol_card persisted: /content/BornToOverfit/data_baseline/data/test_graphs.pkl
#
# --- Sample mol_card (first graph) ---
# [MOL_FEATURES]
# SMILES: CCCCCCCCCCCCCCCCCCCCCCCC(=O)N[C@@H](CO[C@@H]1O[C@H](CO)[C@@H](O)[C@H](O)[C@H]1O)[C@H](O)CCCCCCCCCCCCCCC
# atoms_total: 57
# elements: C=48 N=1 O=8
# molecular_weight: 814.287000
# high_natural_abundance_atoms: 9
# nuclear_spins: 1:1
# halogens_total: 0
# metals_or_other_total: 0
# formal_charge_net: 0
# aromatic_atoms: 0
# ring_atoms: 6
# undirected_bonds: 57
# bond_types: SINGLE=56 DOUBLE=1
# conjugated_bonds: 2
# hybridization: SP2=3 SP3=54
# chirality_centers: 7
# radical_atoms: 0
# tags: ring_system
# [/MOL_FEATURES]
#
# OK: test_graphs.pkl updated and verified.
#
# DONE
# ====================================================================================================

# %% [markdown]
# Load embeddings and models

# %%
# !cp -r /content/drive/MyDrive/MVA/ALTEGRAD/challenge_data/Cam_Raph /content/BornToOverfit/data_baseline/.

# %%
import os
path_to_folder = "/content/BornToOverfit/data_baseline/Cam_Raph/"
path_to_prototype = "/content/BornToOverfit/prototype/"

os.environ['SAVING_FOLDER'] = path_to_prototype + "FULL_model_v3_compat_from_dual_hd256/"
os.environ['SAVING_SUBFOLDER'] = "knn_llm"
os.environ['SAVING_SFT_SUBFOLDER'] = os.environ['SAVING_SUBFOLDER'] + "_sft"
os.environ['GNN_PATH'] = path_to_folder + "model_v3_compat_from_dual_hd256.pt"
os.environ['TRAIN_EMB_PATH'] = path_to_folder + "train_embeddings_RealChemBERT.pt"
os.environ['VAL_EMB_PATH'] = path_to_folder + "validation_embeddings_RealChemBERT.pt"

# %% [markdown]
# Create merged TRAIN/VAL data

# %%
os.environ['DATA_FOLDER'] = "/content/BornToOverfit/data_baseline/data"
os.environ['MERGED_GRAPHS'] = os.environ['DATA_FOLDER'] + "/train_val_graphs.pkl"
# !python data_baseline/merge_embeddings.py \
  --train_path $TRAIN_EMB_PATH \
  --val_path $VAL_EMB_PATH \
  --output_dir $DATA_FOLDER
# Out:
# Loading embeddings from /content/BornToOverfit/data_baseline/Cam_Raph/train_embeddings_RealChemBERT.pt...
#  -> Loaded 31008 embeddings.
# Loading embeddings from /content/BornToOverfit/data_baseline/Cam_Raph/validation_embeddings_RealChemBERT.pt...
#  -> Loaded 1000 embeddings.
# Max Train ID found: 31007. Offset calculated: 31008
# Re-indexing 1000 validation embeddings with offset +31008...
# Merged 31008 + 1000 = 32008 total embeddings.
# Saving 32008 embeddings to /content/BornToOverfit/data_baseline/data/train_val_embeddings.pt...
# Done.

# %%
os.environ['MERGED_EMB'] = os.environ['DATA_FOLDER'] + "/train_val_embeddings.pt"
# !python data_baseline/merge_embeddings.py \
  --train_path $TRAIN_EMB_PATH \
  --val_path $VAL_EMB_PATH \
  --output_dir $DATA_FOLDER
# Out:
# Loading embeddings from /content/BornToOverfit/data_baseline/Cam_Raph/train_embeddings_RealChemBERT.pt...
#  -> Loaded 31008 embeddings.
# Loading embeddings from /content/BornToOverfit/data_baseline/Cam_Raph/validation_embeddings_RealChemBERT.pt...
#  -> Loaded 1000 embeddings.
# Max Train ID found: 31007. Offset calculated: 31008
# Re-indexing 1000 validation embeddings with offset +31008...
# Merged 31008 + 1000 = 32008 total embeddings.
# Saving 32008 embeddings to /content/BornToOverfit/data_baseline/data/train_val_embeddings.pt...
# Done.

# %% [markdown]
# Use all data ?

# %%
USE_ALL_DATA = False
if USE_ALL_DATA:
    os.environ['TRAINING_DATA'] = os.environ['MERGED_EMB']
else:
    os.environ['TRAINING_DATA'] = os.environ['TRAIN_EMB_PATH']

# %% [markdown]
# Fine-tune the LLM with SFT

# %%
os.environ['STEPS'] = '500'
os.environ['MAX_LENGTH'] = '2048'

# %%
# !python prototype/knn_tanimoto_generate.py -f_data data_baseline/data -f $SAVING_FOLDER \
  -gnn_path $GNN_PATH \
  -train_emb_path $TRAINING_DATA \
  --do_finetune \
  --do_sft \
  --k 5 \
  --use_lora \
  --sft_steps $STEPS \
  --sft_lora 128 \
  --sft_neftune \
  --per_device_bs 1 \
  --grad_accum 8 \
  --base_llm deepseek-ai/DeepSeek-R1-Distill-Qwen-1.5B \
  --out_llm_dir $SAVING_SUBFOLDER \
  --max_prompt_length $MAX_LENGTH
# Out:
# 2026-01-11 22:22:36.200937: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-11 22:22:36.216846: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768170156.238198    5289 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768170156.244637    5289 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768170156.260951    5289 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768170156.260980    5289 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768170156.260983    5289 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768170156.260986    5289 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-01-11 22:22:36.265798: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Device: cuda
# Loading binary embeddings from /content/drive/.shortcut-targets-by-id/1gyLyz9sFSaDdhs90gjj0PsrszGffRSnc/Cam_Raph/train_embeddings_RealChemBERT.pt...
# Loading GNN checkpoint: /content/drive/.shortcut-targets-by-id/1gyLyz9sFSaDdhs90gjj0PsrszGffRSnc/Cam_Raph/model_v3_compat_from_dual_hd256.pt
# FILENAME model_v3_compat_from_dual_hd256.pt
# CFG {'pooling': 'sum', 'hidden_dim': 256, 'num_layers': 4, 'num_heads': 4, 'dropout': 0.1, 'out_dim': 768}
# MODEL CLASS MolGNN_GPS_pooling
# Instantiating..
# Loading..
# State loaded odict_keys(['atom_encoder.embeddings.0.weight', 'atom_encoder.embeddings.1.weight', 'atom_encoder.embeddings.2.weight', 'atom_encoder.embeddings.3.weight', 'atom_encoder.embeddings.4.weight', 'atom_encoder.embeddings.5.weight', 'atom_encoder.embeddings.6.weight', 'atom_encoder.embeddings.7.weight', 'atom_encoder.embeddings.8.weight', 'bond_encoder.embeddings.0.weight', 'bond_encoder.embeddings.1.weight', 'bond_encoder.embeddings.2.weight', 'convs.0.conv.eps', 'convs.0.conv.nn.0.weight', 'convs.0.conv.nn.0.bias', 'convs.0.conv.nn.1.weight', 'convs.0.conv.nn.1.bias', 'convs.0.conv.nn.1.running_mean', 'convs.0.conv.nn.1.running_var', 'convs.0.conv.nn.1.num_batches_tracked', 'convs.0.conv.nn.3.weight', 'convs.0.conv.nn.3.bias', 'convs.0.conv.lin.weight', 'convs.0.conv.lin.bias', 'convs.0.attn.in_proj_weight', 'convs.0.attn.in_proj_bias', 'convs.0.attn.out_proj.weight', 'convs.0.attn.out_proj.bias', 'convs.0.mlp.0.weight', 'convs.0.mlp.0.bias', 'convs.0.mlp.3.weight', 'convs.0.mlp.3.bias', 'convs.0.norm1.module.weight', 'convs.0.norm1.module.bias', 'convs.0.norm1.module.running_mean', 'convs.0.norm1.module.running_var', 'convs.0.norm1.module.num_batches_tracked', 'convs.0.norm2.module.weight', 'convs.0.norm2.module.bias', 'convs.0.norm2.module.running_mean', 'convs.0.norm2.module.running_var', 'convs.0.norm2.module.num_batches_tracked', 'convs.0.norm3.module.weight', 'convs.0.norm3.module.bias', 'convs.0.norm3.module.running_mean', 'convs.0.norm3.module.running_var', 'convs.0.norm3.module.num_batches_tracked', 'convs.1.conv.eps', 'convs.1.conv.nn.0.weight', 'convs.1.conv.nn.0.bias', 'convs.1.conv.nn.1.weight', 'convs.1.conv.nn.1.bias', 'convs.1.conv.nn.1.running_mean', 'convs.1.conv.nn.1.running_var', 'convs.1.conv.nn.1.num_batches_tracked', 'convs.1.conv.nn.3.weight', 'convs.1.conv.nn.3.bias', 'convs.1.conv.lin.weight', 'convs.1.conv.lin.bias', 'convs.1.attn.in_proj_weight', 'convs.1.attn.in_proj_bias', 'convs.1.attn.out_proj.weight', 'convs.1.attn.out_proj.bias', 'convs.1.mlp.0.weight', 'convs.1.mlp.0.bias', 'convs.1.mlp.3.weight', 'convs.1.mlp.3.bias', 'convs.1.norm1.module.weight', 'convs.1.norm1.module.bias', 'convs.1.norm1.module.running_mean', 'convs.1.norm1.module.running_var', 'convs.1.norm1.module.num_batches_tracked', 'convs.1.norm2.module.weight', 'convs.1.norm2.module.bias', 'convs.1.norm2.module.running_mean', 'convs.1.norm2.module.running_var', 'convs.1.norm2.module.num_batches_tracked', 'convs.1.norm3.module.weight', 'convs.1.norm3.module.bias', 'convs.1.norm3.module.running_mean', 'convs.1.norm3.module.running_var', 'convs.1.norm3.module.num_batches_tracked', 'convs.2.conv.eps', 'convs.2.conv.nn.0.weight', 'convs.2.conv.nn.0.bias', 'convs.2.conv.nn.1.weight', 'convs.2.conv.nn.1.bias', 'convs.2.conv.nn.1.running_mean', 'convs.2.conv.nn.1.running_var', 'convs.2.conv.nn.1.num_batches_tracked', 'convs.2.conv.nn.3.weight', 'convs.2.conv.nn.3.bias', 'convs.2.conv.lin.weight', 'convs.2.conv.lin.bias', 'convs.2.attn.in_proj_weight', 'convs.2.attn.in_proj_bias', 'convs.2.attn.out_proj.weight', 'convs.2.attn.out_proj.bias', 'convs.2.mlp.0.weight', 'convs.2.mlp.0.bias', 'convs.2.mlp.3.weight', 'convs.2.mlp.3.bias', 'convs.2.norm1.module.weight', 'convs.2.norm1.module.bias', 'convs.2.norm1.module.running_mean', 'convs.2.norm1.module.running_var', 'convs.2.norm1.module.num_batches_tracked', 'convs.2.norm2.module.weight', 'convs.2.norm2.module.bias', 'convs.2.norm2.module.running_mean', 'convs.2.norm2.module.running_var', 'convs.2.norm2.module.num_batches_tracked', 'convs.2.norm3.module.weight', 'convs.2.norm3.module.bias', 'convs.2.norm3.module.running_mean', 'convs.2.norm3.module.running_var', 'convs.2.norm3.module.num_batches_tracked', 'convs.3.conv.eps', 'convs.3.conv.nn.0.weight', 'convs.3.conv.nn.0.bias', 'convs.3.conv.nn.1.weight', 'convs.3.conv.nn.1.bias', 'convs.3.conv.nn.1.running_mean', 'convs.3.conv.nn.1.running_var', 'convs.3.conv.nn.1.num_batches_tracked', 'convs.3.conv.nn.3.weight', 'convs.3.conv.nn.3 ...
# Moving into class..
# Computing global similarity thresholds from Training Data...
# Loading binary embeddings from /content/drive/.shortcut-targets-by-id/1gyLyz9sFSaDdhs90gjj0PsrszGffRSnc/Cam_Raph/train_embeddings_RealChemBERT.pt...
# Encoding training graphs for threshold calibration...
# Loading graphs from: /content/BornToOverfit/data_baseline/data/train_graphs.pkl
# Loaded 31008 graphs
# Saved similarity thresholds to /content/BornToOverfit/prototype/FULL_model_v3_compat_from_dual_hd256/sim_thresholds_k5.json: [0.09926402568817139, 0.15207472443580627, 0.19328847527503967, 0.23858849704265594]
# Building KNN dataset (TRAIN)...
# tokenizer_config.json: 3.07kB [00:00, 12.3MB/s]
# tokenizer.json: 7.03MB [00:00, 72.4MB/s]
# Loading binary embeddings from /content/drive/.shortcut-targets-by-id/1gyLyz9sFSaDdhs90gjj0PsrszGffRSnc/Cam_Raph/train_embeddings_RealChemBERT.pt...
# Phase 1: Computing GNN Embeddings...
# Loading graphs from: /content/BornToOverfit/data_baseline/data/train_graphs.pkl
# Loaded 31008 graphs
# Phase 2: Computing Tanimoto Neighborhoods...
# Computing Fingerprints: 100% 31008/31008 [00:12<00:00, 2573.38it/s]
# Frac None 0.0
# [Train Descriptions] Caching token counts for 31008 items...
# [Train Cards] Caching token counts for 31008 items...
# Building Hybrid Prompts: 100% 31008/31008 [08:24<00:00, 61.46it/s]
# Optimizing memory for SFT...
# GPU Memory Free: 18.36 GB
# Running SFT -> /content/BornToOverfit/prototype/FULL_model_v3_compat_from_dual_hd256/knn_llm_sft
# config.json: 100% 679/679 [00:00<00:00, 6.65MB/s]
# Setting generation max_length to: 2304 (Prompt: 2048 + Gen: 256)
# model.safetensors: 100% 3.55G/3.55G [00:10<00:00, 323MB/s]
# generation_config.json: 100% 181/181 [00:00<00:00, 1.74MB/s]
# trainable params: 147,718,144 || all params: 1,924,806,144 || trainable%: 7.6744
# Map: 100% 31008/31008 [05:22<00:00, 96.04 examples/s]
# Using Custom CausalSeq2SeqTrainer (Decoder-Only detected)
# /content/BornToOverfit/prototype/knn_tanimoto_generate.py:1135: FutureWarning: `tokenizer` is deprecated and will be removed in version 5.0.0 for `CausalSeq2SeqTrainer.__init__`. Use `processing_class` instead.
#   trainer = trainer_cls(
# The model is already on multiple devices. Skipping the move to device specified in `args`.
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'bos_token_id': 151646, 'pad_token_id': 151643}.
#   0% 0/4000 [00:00<?, ?it/s]`use_cache=True` is incompatible with gradient checkpointing. Setting `use_cache=False`.
# {'loss': 0.7471, 'grad_norm': 1.3872183561325073, 'learning_rate': 1.7505e-05, 'epoch': 0.13}
# {'loss': 0.6275, 'grad_norm': 1.603378176689148, 'learning_rate': 1.5005000000000001e-05, 'epoch': 0.26}
# {'loss': 0.5999, 'grad_norm': 1.5625028610229492, 'learning_rate': 1.2505e-05, 'epoch': 0.39}
# {'loss': 0.5781, 'grad_norm': 1.506205439567566, 'learning_rate': 1.0005e-05, 'epoch': 0.52}
# {'loss': 0.5605, 'grad_norm': 1.6049447059631348, 'learning_rate': 7.505e-06, 'epoch': 0.64}
# {'loss': 0.5426, 'grad_norm': 1.4660561084747314, 'learning_rate': 5.0049999999999995e-06, 'epoch': 0.77}
# {'loss': 0.532, 'grad_norm': 1.590687870979309, 'learning_rate': 2.505e-06, 'epoch': 0.9}
# {'loss': 0.532, 'grad_norm': 1.4756196737289429, 'learning_rate': 5e-09, 'epoch': 1.03}
# {'train_runtime': 32159.7702, 'train_samples_per_second': 0.995, 'train_steps_per_second': 0.124, 'train_loss': 0.5899703979492188, 'epoch': 1.03}
# 100% 4000/4000 [8:55:59<00:00,  8.04s/it]

# %% [markdown]
# GRPO

# %%
# !pip install flash-attn --no-build-isolation
# Out:
# Collecting flash-attn
#   Downloading flash_attn-2.8.3.tar.gz (8.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.4/8.4 MB 89.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: torch in /usr/local/lib/python3.12/dist-packages (from flash-attn) (2.9.0+cu126)
# Requirement already satisfied: einops in /usr/local/lib/python3.12/dist-packages (from flash-attn) (0.8.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn) (3.20.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn) (4.15.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn) (75.2.0)
# Requirement already satisfied: sympy>=1.13.3 in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn) (1.14.0)
# Requirement already satisfied: networkx>=2.5.1 in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn) (3.6.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn) (3.1.6)
# Requirement already satisfied: fsspec>=0.8.5 in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn) (2025.3.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn) (12.6.77)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn) (12.6.77)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.6.80 in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn) (12.6.80)
# Requirement already satisfied: nvidia-cudnn-cu12==9.10.2.21 in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn) (9.10.2.21)
# Requirement already satisfied: nvidia-cublas-cu12==12.6.4.1 in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn) (12.6.4.1)
# Requirement already satisfied: nvidia-cufft-cu12==11.3.0.4 in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn) (11.3.0.4)
# Requirement already satisfied: nvidia-curand-cu12==10.3.7.77 in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn) (10.3.7.77)
# Requirement already satisfied: nvidia-cusolver-cu12==11.7.1.2 in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn) (11.7.1.2)
# Requirement already satisfied: nvidia-cusparse-cu12==12.5.4.2 in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn) (12.5.4.2)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.7.1 in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn) (0.7.1)
# Requirement already satisfied: nvidia-nccl-cu12==2.27.5 in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn) (2.27.5)
# Requirement already satisfied: nvidia-nvshmem-cu12==3.3.20 in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn) (3.3.20)
# Requirement already satisfied: nvidia-nvtx-cu12==12.6.77 in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn) (12.6.77)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.6.85 in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn) (12.6.85)
# Requirement already satisfied: nvidia-cufile-cu12==1.11.1.6 in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn) (1.11.1.6)
# Requirement already satisfied: triton==3.5.0 in /usr/local/lib/python3.12/dist-packages (from torch->flash-attn) (3.5.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.12/dist-packages (from sympy>=1.13.3->torch->flash-attn) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->torch->flash-attn) (3.0.3)
# Building wheels for collected packages: flash-attn
#   Building wheel for flash-attn (setup.py) ... done
#   Created wheel for flash-attn: filename=flash_attn-2.8.3-cp312-cp312-linux_x86_64.whl size=253780426 sha256=4e2f9e39313266b1544b68138b15b91ee6221eccf14f7902b7c6620351340810
#   Stored in directory: /root/.cache/pip/wheels/3d/59/46/f282c12c73dd4bb3c2e3fe199f1a0d0f8cec06df0cccfeee27
# Successfully built flash-attn
# Installing collected packages: flash-attn
# Successfully installed flash-attn-2.8.3

# %%
os.environ['SFT_SAVING_FOLDER'] = "/content/drive/MyDrive/MVA/ALTEGRAD/challenge_data/FULL_model_v3_compat_from_dual_hd256/knn_llm_sft"
os.environ['RL_SAVING_FOLDER'] = os.environ['SAVING_SUBFOLDER'] + "_rl"

# !python prototype/knn_tanimoto_generate.py -f_data data_baseline/data -f $SAVING_FOLDER \
  -gnn_path $GNN_PATH \
  -train_emb_path $TRAINING_DATA \
  --do_finetune \
  --rl_algo grpo \
  --k 5 \
  --use_lora \
  --rl_steps $STEPS \
  --bf16 \
  --per_device_bs 1 \
  --num_generations 4 \
  --grad_accum 8 \
  --base_llm $SFT_SAVING_FOLDER \
  --out_llm_dir $RL_SAVING_FOLDER \
  --max_prompt_length $MAX_LENGTH
# Out:
# 2026-01-12 15:30:30.630984: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-12 15:30:30.651244: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768231830.673726   24887 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768231830.680364   24887 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768231830.698226   24887 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768231830.698264   24887 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768231830.698268   24887 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768231830.698271   24887 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-01-12 15:30:30.703437: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Device: cuda
# Loading binary embeddings from /content/drive/.shortcut-targets-by-id/1gyLyz9sFSaDdhs90gjj0PsrszGffRSnc/Cam_Raph/train_embeddings_RealChemBERT.pt...
# Loading GNN checkpoint: /content/drive/.shortcut-targets-by-id/1gyLyz9sFSaDdhs90gjj0PsrszGffRSnc/Cam_Raph/model_v3_compat_from_dual_hd256.pt
# FILENAME model_v3_compat_from_dual_hd256.pt
# CFG {'pooling': 'sum', 'hidden_dim': 256, 'num_layers': 4, 'num_heads': 4, 'dropout': 0.1, 'out_dim': 768}
# MODEL CLASS MolGNN_GPS_pooling
# Instantiating..
# Loading..
# State loaded odict_keys(['atom_encoder.embeddings.0.weight', 'atom_encoder.embeddings.1.weight', 'atom_encoder.embeddings.2.weight', 'atom_encoder.embeddings.3.weight', 'atom_encoder.embeddings.4.weight', 'atom_encoder.embeddings.5.weight', 'atom_encoder.embeddings.6.weight', 'atom_encoder.embeddings.7.weight', 'atom_encoder.embeddings.8.weight', 'bond_encoder.embeddings.0.weight', 'bond_encoder.embeddings.1.weight', 'bond_encoder.embeddings.2.weight', 'convs.0.conv.eps', 'convs.0.conv.nn.0.weight', 'convs.0.conv.nn.0.bias', 'convs.0.conv.nn.1.weight', 'convs.0.conv.nn.1.bias', 'convs.0.conv.nn.1.running_mean', 'convs.0.conv.nn.1.running_var', 'convs.0.conv.nn.1.num_batches_tracked', 'convs.0.conv.nn.3.weight', 'convs.0.conv.nn.3.bias', 'convs.0.conv.lin.weight', 'convs.0.conv.lin.bias', 'convs.0.attn.in_proj_weight', 'convs.0.attn.in_proj_bias', 'convs.0.attn.out_proj.weight', 'convs.0.attn.out_proj.bias', 'convs.0.mlp.0.weight', 'convs.0.mlp.0.bias', 'convs.0.mlp.3.weight', 'convs.0.mlp.3.bias', 'convs.0.norm1.module.weight', 'convs.0.norm1.module.bias', 'convs.0.norm1.module.running_mean', 'convs.0.norm1.module.running_var', 'convs.0.norm1.module.num_batches_tracked', 'convs.0.norm2.module.weight', 'convs.0.norm2.module.bias', 'convs.0.norm2.module.running_mean', 'convs.0.norm2.module.running_var', 'convs.0.norm2.module.num_batches_tracked', 'convs.0.norm3.module.weight', 'convs.0.norm3.module.bias', 'convs.0.norm3.module.running_mean', 'convs.0.norm3.module.running_var', 'convs.0.norm3.module.num_batches_tracked', 'convs.1.conv.eps', 'convs.1.conv.nn.0.weight', 'convs.1.conv.nn.0.bias', 'convs.1.conv.nn.1.weight', 'convs.1.conv.nn.1.bias', 'convs.1.conv.nn.1.running_mean', 'convs.1.conv.nn.1.running_var', 'convs.1.conv.nn.1.num_batches_tracked', 'convs.1.conv.nn.3.weight', 'convs.1.conv.nn.3.bias', 'convs.1.conv.lin.weight', 'convs.1.conv.lin.bias', 'convs.1.attn.in_proj_weight', 'convs.1.attn.in_proj_bias', 'convs.1.attn.out_proj.weight', 'convs.1.attn.out_proj.bias', 'convs.1.mlp.0.weight', 'convs.1.mlp.0.bias', 'convs.1.mlp.3.weight', 'convs.1.mlp.3.bias', 'convs.1.norm1.module.weight', 'convs.1.norm1.module.bias', 'convs.1.norm1.module.running_mean', 'convs.1.norm1.module.running_var', 'convs.1.norm1.module.num_batches_tracked', 'convs.1.norm2.module.weight', 'convs.1.norm2.module.bias', 'convs.1.norm2.module.running_mean', 'convs.1.norm2.module.running_var', 'convs.1.norm2.module.num_batches_tracked', 'convs.1.norm3.module.weight', 'convs.1.norm3.module.bias', 'convs.1.norm3.module.running_mean', 'convs.1.norm3.module.running_var', 'convs.1.norm3.module.num_batches_tracked', 'convs.2.conv.eps', 'convs.2.conv.nn.0.weight', 'convs.2.conv.nn.0.bias', 'convs.2.conv.nn.1.weight', 'convs.2.conv.nn.1.bias', 'convs.2.conv.nn.1.running_mean', 'convs.2.conv.nn.1.running_var', 'convs.2.conv.nn.1.num_batches_tracked', 'convs.2.conv.nn.3.weight', 'convs.2.conv.nn.3.bias', 'convs.2.conv.lin.weight', 'convs.2.conv.lin.bias', 'convs.2.attn.in_proj_weight', 'convs.2.attn.in_proj_bias', 'convs.2.attn.out_proj.weight', 'convs.2.attn.out_proj.bias', 'convs.2.mlp.0.weight', 'convs.2.mlp.0.bias', 'convs.2.mlp.3.weight', 'convs.2.mlp.3.bias', 'convs.2.norm1.module.weight', 'convs.2.norm1.module.bias', 'convs.2.norm1.module.running_mean', 'convs.2.norm1.module.running_var', 'convs.2.norm1.module.num_batches_tracked', 'convs.2.norm2.module.weight', 'convs.2.norm2.module.bias', 'convs.2.norm2.module.running_mean', 'convs.2.norm2.module.running_var', 'convs.2.norm2.module.num_batches_tracked', 'convs.2.norm3.module.weight', 'convs.2.norm3.module.bias', 'convs.2.norm3.module.running_mean', 'convs.2.norm3.module.running_var', 'convs.2.norm3.module.num_batches_tracked', 'convs.3.conv.eps', 'convs.3.conv.nn.0.weight', 'convs.3.conv.nn.0.bias', 'convs.3.conv.nn.1.weight', 'convs.3.conv.nn.1.bias', 'convs.3.conv.nn.1.running_mean', 'convs.3.conv.nn.1.running_var', 'convs.3.conv.nn.1.num_batches_tracked', 'convs.3.conv.nn.3.weight', 'convs.3.conv.nn.3 ...
# Moving into class..
# Computing global similarity thresholds from Training Data...
# Loading binary embeddings from /content/drive/.shortcut-targets-by-id/1gyLyz9sFSaDdhs90gjj0PsrszGffRSnc/Cam_Raph/train_embeddings_RealChemBERT.pt...
# Encoding training graphs for threshold calibration...
# Loading graphs from: /content/BornToOverfit/data_baseline/data/train_graphs.pkl
# Loaded 31008 graphs
# Saved similarity thresholds to /content/BornToOverfit/prototype/FULL_model_v3_compat_from_dual_hd256/sim_thresholds_k5.json: [0.09926402568817139, 0.15207472443580627, 0.19328847527503967, 0.23858849704265594]
# Building KNN dataset (TRAIN)...
# Loading binary embeddings from /content/drive/.shortcut-targets-by-id/1gyLyz9sFSaDdhs90gjj0PsrszGffRSnc/Cam_Raph/train_embeddings_RealChemBERT.pt...
# Phase 1: Computing GNN Embeddings...
# Loading graphs from: /content/BornToOverfit/data_baseline/data/train_graphs.pkl
# Loaded 31008 graphs
# Phase 2: Computing Tanimoto Neighborhoods...
# Computing Fingerprints: 100% 31008/31008 [00:15<00:00, 1955.06it/s]
# Frac None 0.0
# [Train Descriptions] Caching token counts for 31008 items...
# [Train Cards] Caching token counts for 31008 items...
# Building Hybrid Prompts: 100% 31008/31008 [11:30<00:00, 44.90it/s]
# Post-KNN GPU Memory: 5.02 GB
# Optimizing memory for SFT/RL: Moving GNN to CPU and emptying cache...
# GPU Memory Free: 22.49 GB
# Running RL fine-tuning...
#
# [RL] Starting GRPO Fine-tuning on 31008 samples...
# [RL] Loading model with Flash Attention 2 = True...
# `torch_dtype` is deprecated! Use `dtype` instead!
# [RL] Applying chat template to dataset...
# Map: 100% 31008/31008 [00:05<00:00, 5379.92 examples/s]
# <string>:192: FutureWarning: The `max_prompt_length` argument is deprecated and will be removed in version 0.28.0. You should instead filter your dataset before training to ensure that prompts do not exceed your desired length.
# The tokenizer you are loading from '/content/drive/MyDrive/MVA/ALTEGRAD/challenge_data/FULL_model_v3_compat_from_dual_hd256/knn_llm_sft' with an incorrect regex pattern: https://huggingface.co/mistralai/Mistral-Small-3.1-24B-Instruct-2503/discussions/84#69121093e8b480e709447d5e. This will lead to incorrect tokenization. You should set the `fix_mistral_regex=True` flag when loading this tokenizer to fix this issue.
# [RL] Training...
#   0% 0/500 [00:00<?, ?it/s]`generation_config` default values have been modified to match model-specific defaults: {'max_length': 2304}. If this is not desired, please set these values explicitly.
# {'loss': -0.0482, 'grad_norm': 0.8152309656143188, 'learning_rate': 4.909999999999999e-07, 'num_tokens': 155367.0, 'completions/mean_length': 88.4375, 'completions/min_length': 52.7, 'completions/max_length': 142.3, 'completions/clipped_ratio': 0.0, 'completions/mean_terminated_length': 88.4375, 'completions/min_terminated_length': 52.7, 'completions/max_terminated_length': 142.3, 'rewards/bleu_reward/mean': 0.32801830023527145, 'rewards/bleu_reward/std': 0.2181685771793127, 'reward': 0.32801830023527145, 'reward_std': 0.1026931831613183, 'frac_reward_zero_std': 0.05, 'kl': 0.00029670579771554626, 'entropy': 0.7137996383942664, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'step_time': 27.79678016059961, 'epoch': 0.0}
# {'loss': -0.015, 'grad_norm': 0.6479597091674805, 'learning_rate': 4.809999999999999e-07, 'num_tokens': 314581.0, 'completions/mean_length': 93.675, 'completions/min_length': 57.7, 'completions/max_length': 138.8, 'completions/clipped_ratio': 0.0, 'completions/mean_terminated_length': 93.675, 'completions/min_terminated_length': 57.7, 'completions/max_terminated_length': 138.8, 'rewards/bleu_reward/mean': 0.36720957458019254, 'rewards/bleu_reward/std': 0.18610070571303367, 'reward': 0.36720957458019254, 'reward_std': 0.10830495245754719, 'frac_reward_zero_std': 0.0, 'kl': 0.0003188321716861342, 'entropy': 0.7388722917530686, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'step_time': 27.6403141081998, 'epoch': 0.0}
# {'loss': 0.0338, 'grad_norm': 0.570811927318573, 'learning_rate': 4.7099999999999997e-07, 'num_tokens': 465276.0, 'completions/mean_length': 92.3875, 'completions/min_length': 49.3, 'completions/max_length': 141.4, 'completions/clipped_ratio': 0.025, 'completions/mean_terminated_length': 88.89821548461914, 'completions/min_terminated_length': 49.3, 'completions/max_terminated_length': 128.4, 'rewards/bleu_reward/mean': 0.3465971708297729, 'rewards/bleu_reward/std': 0.15334462448954583, 'reward': 0.3465971708297729, 'reward_std': 0.11510162688791752, 'frac_reward_zero_std': 0.0, 'kl': 0.0002973540107689132, 'entropy': 0.6770620217546821, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'step_time': 27.669785078599944, 'epoch': 0.0}
# {'loss': 0.0048, 'grad_norm': 0.924921989440918, 'learning_rate': 4.61e-07, 'num_tokens': 615472.0, 'completions/mean_length': 92.0, 'completions/min_length': 43.5, 'completions/max_length': 166.2, 'completions/clipped_ratio': 0.025, 'completions/mean_terminated_length': 87.72857284545898, 'completions/min_terminated_length': 43.5, 'completions/max_terminated_length': 149.2, 'rewards/bleu_reward/mean': 0.3385129660367966, 'rewards/bleu_reward/std': 0.10854301806539297, 'reward': 0.3385129660367966, 'reward_std': 0.08206157758831978, 'frac_reward_zero_std': 0.0, 'kl': 0.00034477881758903094, 'entropy': 0.8834834521403536, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'step_time': 30.704961964300583, 'epoch': 0.0}
# {'loss': 0.0318, 'grad_norm': 0.4949304163455963, 'learning_rate': 4.51e-07, 'num_tokens': 766834.0, 'completions/mean_length': 98.025, 'completions/min_length': 55.4, 'completions/max_length': 157.5, 'completions/clipped_ratio': 0.0, 'completions/mean_terminated_length': 98.025, 'completions/min_terminated_length': 55.4, 'completions/max_terminated_length': 157.5, 'rewards/bleu_reward/mean': 0.33891416490077975, 'rewards/bleu_reward/std': 0.19490255564451217, 'reward': 0.33891416490077975, 'reward_std': 0.1567441739141941, 'frac_reward_zero_std': 0.0, 'kl': 0.0003211155611893446, 'entropy': 0.6897470286116004, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'step_time': 29.283829414599857, 'epoch': 0.0}
# {'loss': 0.0224, 'grad_norm': 0.7227081060409546, 'learning_rate': 4.41e-07, 'num_tokens': 918840.0, 'completions/mean_length': 99.975, 'completions/min_length': 57.9, 'completions/max_length': 155.9, 'completions/clipped_ratio': 0.0, 'completions/mean_terminated_length': 99.975, 'completions/min_terminated_length': 57.9, 'completions/max_terminated_length': 155.9, 'rewards/bleu_reward/mean': 0.3248328037559986, 'rewards/bleu_reward/std': 0.16876928694546223, 'reward': 0.3248328037559986, 'reward_std': 0.10263408496975898, 'frac_reward_zero_std': 0.0, 'kl': 0.00032857457910498986, 'entropy': 0.8040527585428208, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'step_time': 29.60610302849991, 'epoch': 0.0}
# {'loss': 0.0086, 'grad_norm': 0.777693510055542, 'learning_rate': 4.31e-07, 'num_tokens': 1070698.0, 'completions/mean_length': 83.675, 'completions/min_length': 45.3, 'completions/max_length': 126.3, 'completions/clipped_ratio': 0.0, 'completions/mean_terminated_length': 83.675, 'completions/min_terminated_length': 45.3, 'completions/max_terminated_length': 126.3, 'rewards/bleu_reward/mean': 0.29320044368505477, 'rewards/bleu_reward/std': 0.13862104825675486, 'reward': 0.29320044368505477, 'reward_std': 0.08646863773465156, 'frac_reward_zero_std': 0.0, 'kl': 0.00034187287242275487, 'entropy': 0.8449367980472744, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'step_time': 25.856517236899162, 'epoch': 0.0}
# {'loss': 0.0304, 'grad_norm': 0.49840617179870605, 'learning_rate': 4.2099999999999997e-07, 'num_tokens': 1221437.0, 'completions/mean_length': 95.1375, 'completions/min_length': 56.8, 'completions/max_length': 137.7, 'completions/clipped_ratio': 0.0, 'completions/mean_terminated_length': 95.1375, 'completions/min_terminated_length': 56.8, 'completions/max_terminated_length': 137.7, 'rewards/bleu_reward/mean': 0.33923364579677584, 'rewards/bleu_reward/std': 0.2422323003411293, 'reward': 0.33923364579677584, 'reward_std': 0.11131021156907081, 'frac_reward_zero_std': 0.0, 'kl': 0.0003302652291495178, 'entropy': 0.9563741063699126, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'step_time': 27.30962775069984, 'epoch': 0.01}
# {'loss': -0.0241, 'grad_norm': 0.5676658153533936, 'learning_rate': 4.1099999999999996e-07, 'num_tokens': 1368029.0, 'completions/mean_length': 80.7, 'completions/min_length': 49.0, 'completions/max_length': 124.1, 'completions/clipped_ratio': 0.0, 'completions/mean_terminated_length': 80.7, 'completions/min_terminated_length': 49.0, 'completions/max_terminated_length': 124.1, 'rewards/bleu_reward/mean': 0.34395778775215147, 'rewards/bleu_reward/std': 0.11634516790509224, 'reward': 0.34395778775215147, 'reward_std': 0.09229491651058197, 'frac_reward_zero_std': 0.0, 'kl': 0.0002821548553974651, 'entropy': 0.6414979009889066, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'step_time': 25.447911867400215, 'epoch': 0.01}
# {'loss': -0.0034, 'grad_norm': 0.7097159028053284, 'learning_rate': 4.01e-07, 'num_tokens': 1518176.0, 'completions/mean_length': 87.0375, 'completions/min_length': 49.4, 'completions/max_length': 131.3, 'completions/clipped_ratio': 0.0, 'completions/mean_terminated_length': 87.0375, 'completions/min_terminated_length': 49.4, 'completions/max_terminated_length': 131.3, 'rewards/bleu_reward/mean': 0.354329714179039, 'rewards/bleu_reward/std': 0.1913392748683691, 'reward': 0.354329714179039, 'reward_std': 0.12294619902968407, 'frac_reward_zero_std': 0.0, 'kl': 0.000313664142492609, 'entropy': 0.6922665117541328, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'step_time': 26.774850224199508, 'epoch': 0.01}
# {'loss': 0.0815, 'grad_norm': 0.5983209609985352, 'learning_rate': 3.91e-07, 'num_tokens': 1670901.0, 'completions/mean_length': 96.4625, 'completions/min_length': 51.6, 'completions/max_length': 157.8, 'completions/clipped_ratio': 0.0125, 'completions/mean_terminated_length': 94.175, 'completions/min_terminated_length': 51.6, 'completions/max_terminated_length': 142.0, 'rewards/bleu_reward/mean': 0.3028907783329487, 'rewards/bleu_reward/std': 0.16232852563261985, 'reward': 0.3028907783329487, 'reward_std': 0.11981012225151062, 'frac_reward_zero_std': 0.0, 'kl': 0.00035944006685895147, 'entropy': 0.7916247935965657, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'step_time': 29.474086385398913, 'epoch': 0.01}
# {'loss': 0.0061, 'grad_norm': 0.5213202238082886, 'learning_rate': 3.81e-07, 'num_tokens': 1821095.0, 'completions/mean_length': 86.925, 'completions/min_length': 49.7, 'completions/max_length': 128.5, 'completions/clipped_ratio': 0.0, 'completions/mean_terminated_length': 86.925, 'completions/min_terminated_length': 49.7, 'completions/max_terminated_length': 128.5, 'rewards/bleu_reward/mean': 0.28364367336034774, 'rewards/bleu_reward/std': 0.17910609282553197, 'reward': 0.28364367336034774, 'reward_std': 0.08391681350767613, 'frac_reward_zero_std': 0.0, 'kl': 0.0003517971141604903, 'entropy': 0.8509754292666912, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'step_time': 26.068746032601304, 'epoch': 0.01}
# {'loss': -0.0332, 'grad_norm': 0.7972418069839478, 'learning_rate': 3.71e-07, 'num_tokens': 1971504.0, 'completions/mean_length': 91.1625, 'completions/min_length': 49.9, 'completions/max_length': 161.8, 'completions/clipped_ratio': 0.025, 'completions/mean_terminated_length': 87.39642944335938, 'completions/min_terminated_length': 49.9, 'completions/max_terminated_length': 154.5, 'rewards/bleu_reward/mean': 0.3417634941637516, 'rewards/bleu_reward/std': 0.2140307527035475, 'reward': 0.3417634941637516, 'reward_std': 0.10153635628521443, 'frac_reward_zero_std': 0.0, 'kl': 0.0003320571538550254, 'entropy': 0.8502880966523663, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'step_time': 30.02005830840026, 'epoch': 0.01}
# {'loss': -0.0044, 'grad_norm': 0.7324579954147339, 'learning_rate': 3.6099999999999996e-07, 'num_tokens': 2121744.0, 'completions/mean_length': 90.7, 'completions/min_length': 52.0, 'completions/max_length': 143.8, 'completions/clipped_ratio': 0.0, 'completions/mean_terminated_length': 90.7, 'completions/min_terminated_length': 52.0, 'completions/max_terminated_length': 143.8, 'rewards/bleu_reward/mean': 0.2611568957567215, 'rewards/bleu_reward/std': 0.15685897320508957, 'reward': 0.2611568957567215, 'reward_std': 0.07361711077392101, 'frac_reward_zero_std': 0.0, 'kl': 0.0003800466824486648, 'entropy': 0.9707681158557534, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'step_time': 28.02604178649999, 'epoch': 0.01}
# {'loss': 0.0707, 'grad_norm': 0.8758339285850525, 'learning_rate': 3.5099999999999995e-07, 'num_tokens': 2274395.0, 'completions/mean_length': 97.8875, 'completions/min_length': 48.6, 'completions/max_length': 163.2, 'completions/clipped_ratio': 0.0125, 'completions/mean_terminated_length': 96.3, 'completions/min_terminated_length': 48.6, 'completions/max_terminated_length': 160.8, 'rewards/bleu_reward/mean': 0.3730407640337944, 'rewards/bleu_reward/std': 0.18829070627689362, 'reward': 0.3730407640337944, 'reward_std': 0.11468136645853519, 'frac_reward_zero_std': 0.0, 'kl': 0.0003208770391651683, 'entropy': 0.7531647766940296, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'step_time': 30.186582368300513, 'epoch': 0.01}
# {'loss': -0.0431, 'grad_norm': 0.44364818930625916, 'learning_rate': 3.41e-07, 'num_tokens': 2420061.0, 'completions/mean_length': 94.925, 'completions/min_length': 46.3, 'completions/max_length': 156.9, 'completions/clipped_ratio': 0.0, 'completions/mean_terminated_length': 94.925, 'completions/min_terminated_length': 46.3, 'completions/max_terminated_length': 156.9, 'rewards/bleu_reward/mean': 0.2581909939646721, 'rewards/bleu_reward/std': 0.16923372708261014, 'reward': 0.2581909939646721, 'reward_std': 0.10965626575052738, 'frac_reward_zero_std': 0.0, 'kl': 0.00038628362793247106, 'entropy': 0.9249722533859313, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'step_time': 28.98679849670043, 'epoch': 0.01}
# {'loss': -0.0737, 'grad_norm': 0.34769967198371887, 'learning_rate': 3.31e-07, 'num_tokens': 2573982.0, 'completions/mean_length': 98.0625, 'completions/min_length': 55.3, 'completions/max_length': 154.2, 'completions/clipped_ratio': 0.0125, 'completions/mean_terminated_length': 96.06964340209962, 'completions/min_terminated_length': 55.3, 'completions/max_terminated_length': 142.7, 'rewards/bleu_reward/mean': 0.3642715185880661, 'rewards/bleu_reward/std': 0.1672157660126686, 'reward': 0.3642715185880661, 'reward_std': 0.13592536523938178, 'frac_reward_zero_std': 0.0, 'kl': 0.0003134766664743438, 'entropy': 0.6529044018127024, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'step_time': 29.19813526820035, 'epoch': 0.01}
# {'loss': -0.0448, 'grad_norm': 0.7168782949447632, 'learning_rate': 3.21e-07, 'num_tokens': 2722929.0, 'completions/mean_length': 99.5875, 'completions/min_length': 54.6, 'completions/max_length': 162.4, 'completions/clipped_ratio': 0.0, 'completions/mean_terminated_length': 99.5875, 'completions/min_terminated_length': 54.6, 'completions/max_terminated_length': 162.4, 'rewards/bleu_reward/mean': 0.2876475155353546, 'rewards/bleu_reward/std': 0.14990026950836183, 'reward': 0.2876475155353546, 'reward_std': 0.10266275368630887, 'frac_reward_zero_std': 0.0, 'kl': 0.0003773324566168412, 'entropy': 0.8412445760332048, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'step_time': 30.009525493699403, 'epoch': 0.01}
# {'loss': -0.0353, 'grad_norm': 0.4862634539604187, 'learning_rate': 3.1099999999999997e-07, 'num_tokens': 2876122.0, 'completions/mean_length': 90.9625, 'completions/min_length': 53.3, 'completions/max_length': 139.9, 'completions/clipped_ratio': 0.0, 'completions/mean_terminated_length': 90.9625, 'completions/min_terminated_length': 53.3, 'completions/max_terminated_length': 139.9, 'rewards/bleu_reward/mean': 0.3676088646054268, 'rewards/bleu_reward/std': 0.20638581812381745, 'reward': 0.3676088646054268, 'reward_std': 0.14842471107840538, 'frac_reward_zero_std': 0.0, 'kl': 0.0002898133099602518, 'entropy': 0.6732536351308227, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'step_time': 27.60324532389823, 'epoch': 0.01}
# {'loss': 0.0128, 'grad_norm': 0.7920743823051453, 'learning_rate': 3.0099999999999996e-07, 'num_tokens': 3018223.0, 'completions/mean_length': 86.4125, 'completions/min_length': 45.8, 'completions/max_length': 132.7, 'completions/clipped_ratio': 0.0, 'completions/mean_terminated_length': 86.4125, 'completions/min_terminated_length': 45.8, 'completions/max_terminated_length': 132.7, 'rewards/bleu_reward/mean': 0.2879708096385002, 'rewards/bleu_reward/std': 0.1657836515456438, 'reward': 0.2879708096385002, 'reward_std': 0.10364277362823486, 'frac_reward_zero_std': 0.0, 'kl': 0.00043497611641782894, 'entropy': 0.9846621374599636, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'step_time': 26.289946809299728, 'epoch': 0.01}
# {'loss': 0.0108, 'grad_norm': 0.5671173930168152, 'learning_rate': 2.9099999999999995e-07, 'num_tokens': 3172778.0, 'completions/mean_length': 95.3875, 'completions/min_length': 52.8, 'completions/max_length': 144.2, 'completions/clipped_ratio': 0.0125, 'completions/mean_terminated_length': 93.2125, 'completions/min_terminated_length': 52.8, 'completions/max_terminated_length': 129.7, 'rewards/bleu_reward/mean': 0.36500137150287626, 'rewards/bleu_reward/std': 0.21072714775800705, 'reward': 0.36500137150287626, 'reward_std': 0.1074063241481781, 'frac_reward_zero_std': 0.0, 'kl': 0.0003150934988411791, 'entropy': 0.5924669564701617, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'step_time': 27.95124664980085, 'epoch': 0.01}
# {'loss': 0.01, 'grad_norm': 0.566933274269104, 'learning_rate': 2.8100000000000004e-07, 'num_tokens': 3332855.0, 'completions/mean_length': 109.1625, 'completions/min_length': 64.4, 'completions/max_length': 170.3, 'completions/clipped_ratio': 0.025, 'completions/mean_terminated_length': 105.84583358764648, 'completions/min_terminated_length': 64.4, 'completions/max_terminated_length': 166.4, 'rewards/bleu_reward/mean': 0.3945873752236366, 'rewards/bleu_reward/std': 0.1588789913803339, 'reward': 0.3945873752236366, 'reward_std': 0.13104636073112488, 'frac_reward_zero_std': 0.0, 'kl': 0.00028439878321364633, 'entropy': 0.6751672798767686, 'clip_ratio/low_mean': 0.0, 'clip_ratio/low_min': 0.0, 'clip_ratio/high_mean': 0.0, 'clip_ratio/high_max': 0.0, 'clip_ratio/region_mean': 0.0, 'step_time': 31.288543597800345, 'epoch': 0.01}
#  45% 227/500 [1:47:35<1:56:56, 25.70s/it]

# %% [markdown]
# Generate on validation with the fine-tuned model + evaluation metrics

# %%
os.environ['SFT_SAVING_FOLDER'] = "/content/drive/MyDrive/MVA/ALTEGRAD/challenge_data/FULL_model_v3_compat_from_dual_hd256/knn_llm_sft"
os.environ['NEW_SAVING_FOLDER'] = "/content/drive/MyDrive/MVA/ALTEGRAD/challenge_data/FULL_model_v3_compat_from_dual_hd256/knn_llm_sft_penalized_rep"
os.environ['SAVING_FOLDER'] = "/content/drive/MyDrive/MVA/ALTEGRAD/challenge_data/FULL_model_v3_compat_from_dual_hd256/"

# %%
# !python prototype/knn_tanimoto_generate.py -f_data data_baseline/data -f $SAVING_FOLDER \
  -gnn_path $GNN_PATH \
  -train_emb_path $TRAINING_DATA \
  --do_generate --split validation --k 5 \
  --gen_batch_size 8 \
  --base_llm $SFT_SAVING_FOLDER \
  --out_llm_dir $SFT_SAVING_FOLDER \
  --max_prompt_length $MAX_LENGTH
# Out:
# 2026-01-12 21:24:37.126780: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-12 21:24:37.145093: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768253077.167421    6694 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768253077.174222    6694 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768253077.191376    6694 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768253077.191411    6694 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768253077.191414    6694 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768253077.191418    6694 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-01-12 21:24:37.196279: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Device: cuda
# Loading binary embeddings from /content/drive/.shortcut-targets-by-id/1gyLyz9sFSaDdhs90gjj0PsrszGffRSnc/Cam_Raph/train_embeddings_RealChemBERT.pt...
# Loading GNN checkpoint: /content/drive/.shortcut-targets-by-id/1gyLyz9sFSaDdhs90gjj0PsrszGffRSnc/Cam_Raph/model_v3_compat_from_dual_hd256.pt
# FILENAME model_v3_compat_from_dual_hd256.pt
# CFG {'pooling': 'sum', 'hidden_dim': 256, 'num_layers': 4, 'num_heads': 4, 'dropout': 0.1, 'out_dim': 768}
# MODEL CLASS MolGNN_GPS_pooling
# Instantiating..
# Loading..
# State loaded odict_keys(['atom_encoder.embeddings.0.weight', 'atom_encoder.embeddings.1.weight', 'atom_encoder.embeddings.2.weight', 'atom_encoder.embeddings.3.weight', 'atom_encoder.embeddings.4.weight', 'atom_encoder.embeddings.5.weight', 'atom_encoder.embeddings.6.weight', 'atom_encoder.embeddings.7.weight', 'atom_encoder.embeddings.8.weight', 'bond_encoder.embeddings.0.weight', 'bond_encoder.embeddings.1.weight', 'bond_encoder.embeddings.2.weight', 'convs.0.conv.eps', 'convs.0.conv.nn.0.weight', 'convs.0.conv.nn.0.bias', 'convs.0.conv.nn.1.weight', 'convs.0.conv.nn.1.bias', 'convs.0.conv.nn.1.running_mean', 'convs.0.conv.nn.1.running_var', 'convs.0.conv.nn.1.num_batches_tracked', 'convs.0.conv.nn.3.weight', 'convs.0.conv.nn.3.bias', 'convs.0.conv.lin.weight', 'convs.0.conv.lin.bias', 'convs.0.attn.in_proj_weight', 'convs.0.attn.in_proj_bias', 'convs.0.attn.out_proj.weight', 'convs.0.attn.out_proj.bias', 'convs.0.mlp.0.weight', 'convs.0.mlp.0.bias', 'convs.0.mlp.3.weight', 'convs.0.mlp.3.bias', 'convs.0.norm1.module.weight', 'convs.0.norm1.module.bias', 'convs.0.norm1.module.running_mean', 'convs.0.norm1.module.running_var', 'convs.0.norm1.module.num_batches_tracked', 'convs.0.norm2.module.weight', 'convs.0.norm2.module.bias', 'convs.0.norm2.module.running_mean', 'convs.0.norm2.module.running_var', 'convs.0.norm2.module.num_batches_tracked', 'convs.0.norm3.module.weight', 'convs.0.norm3.module.bias', 'convs.0.norm3.module.running_mean', 'convs.0.norm3.module.running_var', 'convs.0.norm3.module.num_batches_tracked', 'convs.1.conv.eps', 'convs.1.conv.nn.0.weight', 'convs.1.conv.nn.0.bias', 'convs.1.conv.nn.1.weight', 'convs.1.conv.nn.1.bias', 'convs.1.conv.nn.1.running_mean', 'convs.1.conv.nn.1.running_var', 'convs.1.conv.nn.1.num_batches_tracked', 'convs.1.conv.nn.3.weight', 'convs.1.conv.nn.3.bias', 'convs.1.conv.lin.weight', 'convs.1.conv.lin.bias', 'convs.1.attn.in_proj_weight', 'convs.1.attn.in_proj_bias', 'convs.1.attn.out_proj.weight', 'convs.1.attn.out_proj.bias', 'convs.1.mlp.0.weight', 'convs.1.mlp.0.bias', 'convs.1.mlp.3.weight', 'convs.1.mlp.3.bias', 'convs.1.norm1.module.weight', 'convs.1.norm1.module.bias', 'convs.1.norm1.module.running_mean', 'convs.1.norm1.module.running_var', 'convs.1.norm1.module.num_batches_tracked', 'convs.1.norm2.module.weight', 'convs.1.norm2.module.bias', 'convs.1.norm2.module.running_mean', 'convs.1.norm2.module.running_var', 'convs.1.norm2.module.num_batches_tracked', 'convs.1.norm3.module.weight', 'convs.1.norm3.module.bias', 'convs.1.norm3.module.running_mean', 'convs.1.norm3.module.running_var', 'convs.1.norm3.module.num_batches_tracked', 'convs.2.conv.eps', 'convs.2.conv.nn.0.weight', 'convs.2.conv.nn.0.bias', 'convs.2.conv.nn.1.weight', 'convs.2.conv.nn.1.bias', 'convs.2.conv.nn.1.running_mean', 'convs.2.conv.nn.1.running_var', 'convs.2.conv.nn.1.num_batches_tracked', 'convs.2.conv.nn.3.weight', 'convs.2.conv.nn.3.bias', 'convs.2.conv.lin.weight', 'convs.2.conv.lin.bias', 'convs.2.attn.in_proj_weight', 'convs.2.attn.in_proj_bias', 'convs.2.attn.out_proj.weight', 'convs.2.attn.out_proj.bias', 'convs.2.mlp.0.weight', 'convs.2.mlp.0.bias', 'convs.2.mlp.3.weight', 'convs.2.mlp.3.bias', 'convs.2.norm1.module.weight', 'convs.2.norm1.module.bias', 'convs.2.norm1.module.running_mean', 'convs.2.norm1.module.running_var', 'convs.2.norm1.module.num_batches_tracked', 'convs.2.norm2.module.weight', 'convs.2.norm2.module.bias', 'convs.2.norm2.module.running_mean', 'convs.2.norm2.module.running_var', 'convs.2.norm2.module.num_batches_tracked', 'convs.2.norm3.module.weight', 'convs.2.norm3.module.bias', 'convs.2.norm3.module.running_mean', 'convs.2.norm3.module.running_var', 'convs.2.norm3.module.num_batches_tracked', 'convs.3.conv.eps', 'convs.3.conv.nn.0.weight', 'convs.3.conv.nn.0.bias', 'convs.3.conv.nn.1.weight', 'convs.3.conv.nn.1.bias', 'convs.3.conv.nn.1.running_mean', 'convs.3.conv.nn.1.running_var', 'convs.3.conv.nn.1.num_batches_tracked', 'convs.3.conv.nn.3.weight', 'convs.3.conv.nn.3 ...
# Moving into class..
# Loaded similarity thresholds from /content/drive/MyDrive/MVA/ALTEGRAD/challenge_data/FULL_model_v3_compat_from_dual_hd256/sim_thresholds_k5.json: [0.09926402568817139, 0.15207472443580627, 0.19328847527503967, 0.23858849704265594]
# Generating with model: /content/drive/MyDrive/MVA/ALTEGRAD/challenge_data/FULL_model_v3_compat_from_dual_hd256/knn_llm_sft
# Loading LLM and Tokenizer from /content/drive/MyDrive/MVA/ALTEGRAD/challenge_data/FULL_model_v3_compat_from_dual_hd256/knn_llm_sft...
#  [Context Detection] Model native limit: 131072
#  [Context Detection] Capping context to 2048 for memory safety.
# Loading Data & Caches...
# [Train Descriptions] Caching token counts for 31008 items...
# [Train Cards] Caching token counts for 31008 items...
# Loading binary embeddings from /content/drive/.shortcut-targets-by-id/1gyLyz9sFSaDdhs90gjj0PsrszGffRSnc/Cam_Raph/train_embeddings_RealChemBERT.pt...
# Phase 1: Computing Query GNN Embeddings...
# Loading graphs from: /content/BornToOverfit/data_baseline/data/validation_graphs.pkl
# Loaded 1000 graphs
# Retrieving Semantic Neighbors (k=5 candidate pool)...
# Phase 2: Computing Fingerprints & Structural Neighbors...
# Computing Fingerprints: 100% 31008/31008 [00:11<00:00, 2758.18it/s]
# Frac None 0.0
# Computing Fingerprints: 100% 1000/1000 [00:00<00:00, 2669.86it/s]
# Frac None 0.0
# Building Hybrid Prompts...
# Constructing: 100% 1000/1000 [00:13<00:00, 72.12it/s]
# Sorting data by prompt length (Batch Padding Optimization)...
# Generating with Batch Size 8...
# Generating:   0% 0/125 [00:00<?, ?it/s]`generation_config` default values have been modified to match model-specific defaults: {'max_length': 2304, 'bos_token_id': 151646}. If this is not desired, please set these values explicitly.
# Generating:  25% 31/125 [03:41<13:25,  8.57s/it]

# %% [markdown]
# Generate on test (no references; no evaluation)

# %%
# !python prototype/knn_tanimoto_generate.py -f_data data_baseline/data -f $SAVING_FOLDER \
  -gnn_path $GNN_PATH \
  -train_emb_path $TRAINING_DATA \
  --do_generate --split test --k 5 \
  --gen_batch_size 8 \
  --out_llm_dir $SAVING_SFT_SUBFOLDER \
  --max_prompt_length $MAX_LENGTH
# Out:
# 2026-01-12 07:53:47.585782: I tensorflow/core/util/port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2026-01-12 07:53:47.603212: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1768204427.624439  152392 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1768204427.630954  152392 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1768204427.647200  152392 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768204427.647228  152392 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768204427.647231  152392 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1768204427.647233  152392 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2026-01-12 07:53:47.652101: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# Device: cuda
# Loading binary embeddings from /content/drive/.shortcut-targets-by-id/1gyLyz9sFSaDdhs90gjj0PsrszGffRSnc/Cam_Raph/train_embeddings_RealChemBERT.pt...
# Loading GNN checkpoint: /content/drive/.shortcut-targets-by-id/1gyLyz9sFSaDdhs90gjj0PsrszGffRSnc/Cam_Raph/model_v3_compat_from_dual_hd256.pt
# FILENAME model_v3_compat_from_dual_hd256.pt
# CFG {'pooling': 'sum', 'hidden_dim': 256, 'num_layers': 4, 'num_heads': 4, 'dropout': 0.1, 'out_dim': 768}
# MODEL CLASS MolGNN_GPS_pooling
# Instantiating..
# Loading..
# State loaded odict_keys(['atom_encoder.embeddings.0.weight', 'atom_encoder.embeddings.1.weight', 'atom_encoder.embeddings.2.weight', 'atom_encoder.embeddings.3.weight', 'atom_encoder.embeddings.4.weight', 'atom_encoder.embeddings.5.weight', 'atom_encoder.embeddings.6.weight', 'atom_encoder.embeddings.7.weight', 'atom_encoder.embeddings.8.weight', 'bond_encoder.embeddings.0.weight', 'bond_encoder.embeddings.1.weight', 'bond_encoder.embeddings.2.weight', 'convs.0.conv.eps', 'convs.0.conv.nn.0.weight', 'convs.0.conv.nn.0.bias', 'convs.0.conv.nn.1.weight', 'convs.0.conv.nn.1.bias', 'convs.0.conv.nn.1.running_mean', 'convs.0.conv.nn.1.running_var', 'convs.0.conv.nn.1.num_batches_tracked', 'convs.0.conv.nn.3.weight', 'convs.0.conv.nn.3.bias', 'convs.0.conv.lin.weight', 'convs.0.conv.lin.bias', 'convs.0.attn.in_proj_weight', 'convs.0.attn.in_proj_bias', 'convs.0.attn.out_proj.weight', 'convs.0.attn.out_proj.bias', 'convs.0.mlp.0.weight', 'convs.0.mlp.0.bias', 'convs.0.mlp.3.weight', 'convs.0.mlp.3.bias', 'convs.0.norm1.module.weight', 'convs.0.norm1.module.bias', 'convs.0.norm1.module.running_mean', 'convs.0.norm1.module.running_var', 'convs.0.norm1.module.num_batches_tracked', 'convs.0.norm2.module.weight', 'convs.0.norm2.module.bias', 'convs.0.norm2.module.running_mean', 'convs.0.norm2.module.running_var', 'convs.0.norm2.module.num_batches_tracked', 'convs.0.norm3.module.weight', 'convs.0.norm3.module.bias', 'convs.0.norm3.module.running_mean', 'convs.0.norm3.module.running_var', 'convs.0.norm3.module.num_batches_tracked', 'convs.1.conv.eps', 'convs.1.conv.nn.0.weight', 'convs.1.conv.nn.0.bias', 'convs.1.conv.nn.1.weight', 'convs.1.conv.nn.1.bias', 'convs.1.conv.nn.1.running_mean', 'convs.1.conv.nn.1.running_var', 'convs.1.conv.nn.1.num_batches_tracked', 'convs.1.conv.nn.3.weight', 'convs.1.conv.nn.3.bias', 'convs.1.conv.lin.weight', 'convs.1.conv.lin.bias', 'convs.1.attn.in_proj_weight', 'convs.1.attn.in_proj_bias', 'convs.1.attn.out_proj.weight', 'convs.1.attn.out_proj.bias', 'convs.1.mlp.0.weight', 'convs.1.mlp.0.bias', 'convs.1.mlp.3.weight', 'convs.1.mlp.3.bias', 'convs.1.norm1.module.weight', 'convs.1.norm1.module.bias', 'convs.1.norm1.module.running_mean', 'convs.1.norm1.module.running_var', 'convs.1.norm1.module.num_batches_tracked', 'convs.1.norm2.module.weight', 'convs.1.norm2.module.bias', 'convs.1.norm2.module.running_mean', 'convs.1.norm2.module.running_var', 'convs.1.norm2.module.num_batches_tracked', 'convs.1.norm3.module.weight', 'convs.1.norm3.module.bias', 'convs.1.norm3.module.running_mean', 'convs.1.norm3.module.running_var', 'convs.1.norm3.module.num_batches_tracked', 'convs.2.conv.eps', 'convs.2.conv.nn.0.weight', 'convs.2.conv.nn.0.bias', 'convs.2.conv.nn.1.weight', 'convs.2.conv.nn.1.bias', 'convs.2.conv.nn.1.running_mean', 'convs.2.conv.nn.1.running_var', 'convs.2.conv.nn.1.num_batches_tracked', 'convs.2.conv.nn.3.weight', 'convs.2.conv.nn.3.bias', 'convs.2.conv.lin.weight', 'convs.2.conv.lin.bias', 'convs.2.attn.in_proj_weight', 'convs.2.attn.in_proj_bias', 'convs.2.attn.out_proj.weight', 'convs.2.attn.out_proj.bias', 'convs.2.mlp.0.weight', 'convs.2.mlp.0.bias', 'convs.2.mlp.3.weight', 'convs.2.mlp.3.bias', 'convs.2.norm1.module.weight', 'convs.2.norm1.module.bias', 'convs.2.norm1.module.running_mean', 'convs.2.norm1.module.running_var', 'convs.2.norm1.module.num_batches_tracked', 'convs.2.norm2.module.weight', 'convs.2.norm2.module.bias', 'convs.2.norm2.module.running_mean', 'convs.2.norm2.module.running_var', 'convs.2.norm2.module.num_batches_tracked', 'convs.2.norm3.module.weight', 'convs.2.norm3.module.bias', 'convs.2.norm3.module.running_mean', 'convs.2.norm3.module.running_var', 'convs.2.norm3.module.num_batches_tracked', 'convs.3.conv.eps', 'convs.3.conv.nn.0.weight', 'convs.3.conv.nn.0.bias', 'convs.3.conv.nn.1.weight', 'convs.3.conv.nn.1.bias', 'convs.3.conv.nn.1.running_mean', 'convs.3.conv.nn.1.running_var', 'convs.3.conv.nn.1.num_batches_tracked', 'convs.3.conv.nn.3.weight', 'convs.3.conv.nn.3 ...
# Moving into class..
# Loaded similarity thresholds from /content/BornToOverfit/prototype/FULL_model_v3_compat_from_dual_hd256/sim_thresholds_k5.json: [0.09926402568817139, 0.15207472443580627, 0.19328847527503967, 0.23858849704265594]
# Generating with model: /content/BornToOverfit/prototype/FULL_model_v3_compat_from_dual_hd256/knn_llm_sft
# Loading LLM and Tokenizer from /content/BornToOverfit/prototype/FULL_model_v3_compat_from_dual_hd256/knn_llm_sft...
# The tokenizer you are loading from '/content/BornToOverfit/prototype/FULL_model_v3_compat_from_dual_hd256/knn_llm_sft' with an incorrect regex pattern: https://huggingface.co/mistralai/Mistral-Small-3.1-24B-Instruct-2503/discussions/84#69121093e8b480e709447d5e. This will lead to incorrect tokenization. You should set the `fix_mistral_regex=True` flag when loading this tokenizer to fix this issue.
#  [Context Detection] Model native limit: 131072
#  [Context Detection] Capping context to 2048 for memory safety.
# The tokenizer you are loading from '/content/BornToOverfit/prototype/FULL_model_v3_compat_from_dual_hd256/knn_llm_sft' with an incorrect regex pattern: https://huggingface.co/mistralai/Mistral-Small-3.1-24B-Instruct-2503/discussions/84#69121093e8b480e709447d5e. This will lead to incorrect tokenization. You should set the `fix_mistral_regex=True` flag when loading this tokenizer to fix this issue.
# Loading Data & Caches...
# [Train Descriptions] Caching token counts for 31008 items...
# [Train Cards] Caching token counts for 31008 items...
# Loading binary embeddings from /content/drive/.shortcut-targets-by-id/1gyLyz9sFSaDdhs90gjj0PsrszGffRSnc/Cam_Raph/train_embeddings_RealChemBERT.pt...
# Phase 1: Computing Query GNN Embeddings...
# Loading graphs from: /content/BornToOverfit/data_baseline/data/test_graphs.pkl
# Loaded 1000 graphs
# Retrieving Semantic Neighbors (k=5 candidate pool)...
# Phase 2: Computing Fingerprints & Structural Neighbors...
# Computing Fingerprints: 100% 31008/31008 [00:12<00:00, 2583.20it/s]
# Frac None 0.0
# Computing Fingerprints: 100% 1000/1000 [00:00<00:00, 2702.84it/s]
# Frac None 0.0
# Building Hybrid Prompts...
# Constructing: 100% 1000/1000 [00:13<00:00, 72.72it/s]
# Sorting data by prompt length (Batch Padding Optimization)...
# Generating with Batch Size 8...
# Generating:   0% 0/125 [00:00<?, ?it/s]`generation_config` default values have been modified to match model-specific defaults: {'max_length': 2304, 'bos_token_id': 151646}. If this is not desired, please set these values explicitly.
# Generating: 100% 125/125 [17:45<00:00,  8.53s/it]

# %% [markdown]
# See generated data on the test set

# %%
import pandas as pd
os.environ['FINAL_SAVING_FOLDER'] = os.environ['SAVING_FOLDER'][:-1]
test = pd.read_csv(os.environ['FINAL_SAVING_FOLDER'] + "/test_knn_gen_k5.csv")
test
# Out:
#       ID                                             Prompt  \
# 0    130  You are an expert chemist. Generate a factual ...
# 1    615  You are an expert chemist. Generate a factual ...
# 2    103  You are an expert chemist. Generate a factual ...
# 3    119  You are an expert chemist. Generate a factual ...
# 4    404  You are an expert chemist. Generate a factual ...
# ..   ...                                                ...
# 995   14  You are an expert chemist. Generate a factual ...
# 996  751  You are an expert chemist. Generate a factual ...
# 997  998  You are an expert chemist. Generate a factual ...
# 998  995  You are an expert chemist. Generate a factual ...
# 999  596  You are an expert chemist. Generate a factual ...
#
#                                  generated_description    NN1    NN2      NN3  \
# 0    The molecule is the stable isotope of zinc wit...  14677   2289      NaN
# 1    The molecule is an organic heteroatom that con...  14484  17988      NaN
# 2    The molecule is the stable isotope of yttrium ...  27655   2289      NaN
# 3    The molecule is an alkane that is octane subst...  12729  22545      NaN
# 4    The molecule is an organosulfur heterocycle th...   5290  27029      NaN
# ..                                                 ...    ...    ...      ...
# 995  The molecule is a pseudoguaianolide with anti-...   2601  22872      1.0
# 996  The molecule is a diterpenoid that is 6a,7,8,1...  11015  19168  10235.0
# 997  The molecule is an L-alpha-amino acid ester re...  11088  23286  20439.0
# 998  The molecule is an alkyl cinnamate obtained by...  28494   6409   3907.0
# 999  The molecule is the hydrochloride salt of enal...   5382  14232  25723.0
#
#          NN4      NN5
# 0        NaN      NaN
# 1        NaN      NaN
# 2        NaN      NaN
# 3        NaN      NaN
# 4        NaN      NaN
# ..       ...      ...
# 995  20660.0   7049.0
# 996  22987.0  13686.0
# 997  20537.0   3658.0
# 998    685.0   2544.0
# 999   2075.0  25711.0
#
# [1000 rows x 8 columns]

# %%
print(test.iloc[18]["Prompt"])
print(test.iloc[18]["generated_description"])
# Out:
# You are an expert chemist. Generate a factual description of the [QUERY MOLECULE] strictly based on its feature card.
#
# **Context Guidelines:**
# * **[STRUCTURAL TEMPLATES]:** Use these molecules to determine sentence structure, IUPAC nomenclature style, and general scaffold description. **CAUTION:** Even if high similarity, specific atoms or groups may differ. Do NOT infer chemical properties (e.g., bond counts, specific substituents) from templates unless they exist in the Query Card.
# * **[FUNCTIONAL REFERENCES]:** Use these to identify potential abstract biomedical roles (e.g., 'anti-bacterial', 'metabolite'). **CAUTION:** These may be chemically distant. **NEVER** copy physical numbers (Mass, Spin) or specific bio-activity data unless supported by the [QUERY MOLECULE] structure.
#
# **Strict Constraints:**
# 1. The [QUERY MOLECULE] Card is the ABSOLUTE GROUND TRUTH.
# 2. If a neighbor contradicts the Query, IGNORE the neighbor.
# 3. Never mention 'Neighbor' or 'Template' in the final output.
#
# [QUERY MOLECULE]
# Card: [MOL_FEATURES]
# SMILES: N[NH3+]
# atoms_total: 2
# elements: N=2
# molecular_weight: 33.054000
# high_natural_abundance_atoms: 2
# nuclear_spins: 1:2
# halogens_total: 0
# metals_or_other_total: 0
# formal_charge_net: 1
# aromatic_atoms: 0
# ring_atoms: 0
# undirected_bonds: 1
# bond_types: SINGLE=1
# conjugated_bonds: 0
# hybridization: SP3=2
# chirality_centers: 0
# radical_atoms: 0
# tags: net_positive_charge(+1); heteroatom_rich
# [/MOL_FEATURES]
#
# [CONTEXT]
# [STRUCTURAL TEMPLATES]
# > Template 1 (Tanimoto: 0.25):
# Card: [MOL_FEATURES]
# SMILES: NN
# atoms_total: 2
# elements: N=2
# molecular_weight: 32.046000
# high_natural_abundance_atoms: 2
# nuclear_spins: 1:2
# halogens_total: 0
# metals_or_other_total: 0
# formal_charge_net: 0
# aromatic_atoms: 0
# ring_atoms: 0
# undirected_bonds: 1
# bond_types: SINGLE=1
# conjugated_bonds: 0
# hybridization: SP3=2
# chirality_centers: 0
# radical_atoms: 0
# tags: heteroatom_rich
# [/MOL_FEATURES]
# Description: The molecule is an azane and a member of hydrazines. It has a role as an EC 4.3.1.10 (serine-sulfate ammonia-lyase) inhibitor. It is a conjugate base of a hydrazinium(1+). It is a conjugate acid of a hydrazinide.
#
# [FUNCTIONAL REFERENCE]
# > Ref 1 (Cosine: 0.30):
# Description: The molecule is the stable isotope of helium with relative atomic mass 4.002603. The most abundant (99.99 atom percent) isotope of naturally occurring helium. It contains an alpha-particle.
# [/CONTEXT]
# **Generate the description strictly adhering to the Guidelines:**
# The molecule is a hydrazinium ion that is the conjugate acid of hydrazine, arising from protonation of one of the nitrogen atoms. It is a conjugate acid of a hydrazine.

# %% [markdown]
# Saving to Drive

# %%
# !cp -r $FINAL_SAVING_FOLDER /content/drive/MyDrive/MVA/ALTEGRAD/challenge_data/.
